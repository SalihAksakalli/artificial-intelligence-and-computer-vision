# %%
# library
from keras.preprocessing.image import load_img

# %%
# reading/loading image
img = load_img("C:/Users/pc/Desktop/Yapay Zeka ile Bilgisayarlı Görü/deep_learning_keras/introduction_to_cv/datasets/starwars/yoda.jpg")

print(img, end="\n\n")

print("Type:",type(img))
print("Format:",img.format)
print("Size:",img.size)
print("Mode:",img.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x481 at 0x17170990E90>
#
# Type: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Format: JPEG
# Size: (500, 481)
# Mode: RGB

# %%
# displaying image
# pip install matplotlib
import matplotlib.pyplot as plt
img = load_img("C:/Users/pc/Desktop/Yapay Zeka ile Bilgisayarlı Görü/deep_learning_keras/introduction_to_cv/datasets/starwars/yoda.jpg")
img1 = load_img("C:/Users/pc/Desktop/Yapay Zeka ile Bilgisayarlı Görü/deep_learning_keras/introduction_to_cv/datasets/starwars/clone.jpg")

plt.imshow(img)
plt.show()

plt.imshow(img1)
plt.show()

# %%
# PIL --> numpy array
from keras.preprocessing.image import load_img, img_to_array, array_to_img

img = load_img("C:/Users/pc/Desktop/Yapay Zeka ile Bilgisayarlı Görü/deep_learning_keras/introduction_to_cv/datasets/starwars/yoda.jpg")
print("Type:",type(img))

img = img_to_array(img)
print("Type:",type(img))


# numpy array --> PIL
img = array_to_img(img)
print("Type:",type(img))
# Out:
# Type: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Type: <class 'numpy.ndarray'>
# Type: <class 'PIL.Image.Image'>
